# %%
from pptx import Presentation
from pptx.util import Inches, Pt

# Create a PowerPoint presentation
prs = Presentation()

# Add a slide with a blank layout
slide = prs.slides.add_slide(prs.slide_layouts[5])

# Fixed table width and varied heights for three tables
table_width = Inches(4)
table_heights = [Inches(1.5), Inches(2), Inches(2)]

# Define the data for the tables
company_details = [
    ["Company Details"],
    ["WEBSITE"],
    ["HQ ADDRESS"],
    ["ANNUAL GROWTH"],
    ["# OF EMPLOYEES"],
    ["INDUSTRY"]
]

key_contacts = [
    ["Key Contacts"],
    ["CEO/Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Finance", "Kartikeya\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
    ["Co-CEO/Co-Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Sales", "Gannuji\nph no:23234234\nmail:ganuradhakrish@gmail.com"]
]

rv_info = [
    ["RV Info"],
    ["WCIS_ID"],
    ["WCIS_SUP_ID"],
    ["WCIS_STATUS"],
    ["BDO"],
    ["RM"],
    ["Coverage Leads"],
    ["Last call reported by"],
    ["Last call reported on"],
    ["Call Logs"],
    ["Similar companies"]
]

# Define table data and positions
tables_data = [company_details, key_contacts, rv_info]
table_positions = [(Inches(0.5), Inches(1)), (Inches(0.5), Inches(2.7)), (Inches(0.5), Inches(5))]

# Add tables to the slide
for i, (data, (x, y)) in enumerate(zip(tables_data, table_positions)):
    # Ensure all rows have the same number of columns
    max_cols = max(len(row) for row in data)
    padded_data = [row + [""] * (max_cols - len(row)) for row in data]

    rows, cols = len(padded_data), max_cols
    table = slide.shapes.add_table(rows, cols, x, y, table_width, table_heights[i]).table

    # Set column widths
    for col in range(cols):
        table.columns[col].width = table_width // cols

    # Populate table with data
    for row_idx, row_data in enumerate(padded_data):
        for col_idx, cell_data in enumerate(row_data):
            table.cell(row_idx, col_idx).text = cell_data
            # Adjust font size
            for paragraph in table.cell(row_idx, col_idx).text_frame.paragraphs:
                for run in paragraph.runs:
                    run.font.size = Pt(10)

# Save the presentation
prs.save("three_tables_slide.pptx")
print("PowerPoint presentation with tables created!")
# Out:
# PowerPoint presentation with tables created!

# %%
pip install python-pptx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 15.0 MB/s eta 0:00:00
# ...

# %%
from pptx import Presentation
from pptx.util import Inches, Pt

# Create a PowerPoint presentation
prs = Presentation()

# Add a slide with a blank layout
slide = prs.slides.add_slide(prs.slide_layouts[5])

# Fixed table width and heights for three tables
table_width = Inches(4)
table_heights = [Inches(1.5), Inches(2), Inches(2)]  # Heights of individual tables

# Define the data for the tables
company_details = [
    ["Company Details"],
    ["WEBSITE"],
    ["HQ ADDRESS"],
    ["ANNUAL GROWTH"],
    ["# OF EMPLOYEES"],
    ["INDUSTRY"]
]

key_contacts = [
    ["Key Contacts"],
    ["CEO/Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Finance", "Kartikeya\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
    ["Co-CEO/Co-Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Sales", "Gannuji\nph no:23234234\nmail:ganuradhakrish@gmail.com"]
]

rv_info = [
    ["RV Info"],
    ["WCIS_ID"],
    ["WCIS_SUP_ID"],
    ["WCIS_STATUS"],
    ["BDO"],
    ["RM"],
    ["Coverage Leads"],
    ["Last call reported by"],
    ["Last call reported on"],
    ["Call Logs"],
    ["Similar companies"]
]

# Define table data
tables_data = [company_details, key_contacts, rv_info]

# Start position for the first table and spacing between tables
x_pos = Inches(0.5)  # Fixed horizontal position
y_pos_start = Inches(1)  # Initial vertical position
spacing = Inches(0.5)  # Space between tables

# Add tables to the slide
y_pos = y_pos_start
for i, (data, height) in enumerate(zip(tables_data, table_heights)):
    # Ensure all rows have the same number of columns
    max_cols = max(len(row) for row in data)
    padded_data = [row + [""] * (max_cols - len(row)) for row in data]

    rows, cols = len(padded_data), max_cols
    table = slide.shapes.add_table(rows, cols, x_pos, y_pos, table_width, height).table

    # Set column widths
    for col in range(cols):
        table.columns[col].width = table_width // cols

    # Populate table with data
    for row_idx, row_data in enumerate(padded_data):
        for col_idx, cell_data in enumerate(row_data):
            table.cell(row_idx, col_idx).text = cell_data
            # Adjust font size
            for paragraph in table.cell(row_idx, col_idx).text_frame.paragraphs:
                for run in paragraph.runs:
                    run.font.size = Pt(10)

    # Update vertical position for the next table
    y_pos += height + spacing

# Save the presentation
prs.save("three_tables_no_overlap.pptx")
print("PowerPoint presentation with tables created without overlapping!")
# Out:
# PowerPoint presentation with tables created without overlapping!

# %%
from pptx import Presentation
from pptx.util import Inches, Pt

# Create a PowerPoint presentation
prs = Presentation()

# Add a slide with a blank layout
slide = prs.slides.add_slide(prs.slide_layouts[5])

# Fixed table width and heights for three tables
table_width = Inches(4)
table_heights = [Inches(1.5), Inches(2), Inches(2)]  # Heights of individual tables

# Define the data for the tables
company_details = [
    ["Company Details"],
    ["WEBSITE"],
    ["HQ ADDRESS"],
    ["ANNUAL GROWTH"],
    ["# OF EMPLOYEES"],
    ["INDUSTRY"]
]

key_contacts = [
    ["Key Contacts"],
    ["CEO/Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Finance", "Kartikeya\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
    ["Co-CEO/Co-Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Sales", "Gannuji\nph no:23234234\nmail:ganuradhakrish@gmail.com"]
]

rv_info = [
    ["RV Info"],
    ["WCIS_ID"],
    ["WCIS_SUP_ID"],
    ["WCIS_STATUS"],
    ["BDO"],
    ["RM"],
    ["Coverage Leads"],
    ["Last call reported by"],
    ["Last call reported on"],
    ["Call Logs"],
    ["Similar companies"]
]

# Define table data
tables_data = [company_details, key_contacts, rv_info]

# Constants for slide layout
slide_height = prs.slide_height  # Slide height in EMUs
top_margin = Inches(0.5)  # Top margin to avoid overlapping with title section
bottom_margin = Inches(0.5)  # Bottom margin to prevent overflow
available_height = slide_height - top_margin - bottom_margin

# Calculate dynamic spacing
total_table_height = sum(table_heights)
remaining_space = available_height - total_table_height
spacing = remaining_space / (len(tables_data) - 1) if len(tables_data) > 1 else 0

# Start position for the first table
x_pos = Inches(0.5)  # Fixed horizontal position
y_pos = top_margin  # Start below the top margin

# Add tables to the slide
for i, (data, height) in enumerate(zip(tables_data, table_heights)):
    # Ensure all rows have the same number of columns
    max_cols = max(len(row) for row in data)
    padded_data = [row + [""] * (max_cols - len(row)) for row in data]

    rows, cols = len(padded_data), max_cols
    table = slide.shapes.add_table(rows, cols, x_pos, y_pos, table_width, height).table

    # Set column widths
    for col in range(cols):
        table.columns[col].width = table_width // cols

    # Populate table with data
    for row_idx, row_data in enumerate(padded_data):
        for col_idx, cell_data in enumerate(row_data):
            table.cell(row_idx, col_idx).text = cell_data
            # Adjust font size
            for paragraph in table.cell(row_idx, col_idx).text_frame.paragraphs:
                for run in paragraph.runs:
                    run.font.size = Pt(10)

    # Update vertical position for the next table
    y_pos += height + spacing

# Save the presentation
prs.save("three_tables_aligned.pptx")
print("PowerPoint presentation with evenly spaced tables created!")
# Out:
# PowerPoint presentation with evenly spaced tables created!

# %%
from pptx import Presentation
from pptx.util import Inches, Pt

# Create a PowerPoint presentation
prs = Presentation()

# Add a slide with a blank layout
slide = prs.slides.add_slide(prs.slide_layouts[5])

# Fixed table width
table_width = Inches(4)

# Define the data for the tables
company_details = [
    ["Company Details"],
    ["WEBSITE"],
    ["HQ ADDRESS"],
    ["ANNUAL GROWTH"],
    ["# OF EMPLOYEES"],
    ["INDUSTRY"]
]

key_contacts = [
    ["Key Contacts"],
    ["CEO/Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Finance", "Kartikeya\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
    ["Co-CEO/Co-Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Sales", "Gannuji\nph no:23234234\nmail:ganuradhakrish@gmail.com"]
]

rv_info = [
    ["RV Info"],
    ["WCIS_ID"],
    ["WCIS_SUP_ID"],
    ["WCIS_STATUS"],
    ["BDO"],
    ["RM"],
    ["Coverage Leads"],
    ["Last call reported by"],
    ["Last call reported on"],
    ["Call Logs"],
    ["Similar companies"]
]

# Define table data
tables_data = [company_details, key_contacts, rv_info]
table_heights = [Inches(1.5), Inches(2), Inches(2)]  # Heights of individual tables

# Constants for slide layout
slide_height = prs.slide_height  # Slide height in EMUs
top_margin = Inches(1)  # Top margin to avoid overlapping with the title section
bottom_margin = Inches(0.5)  # Bottom margin to prevent overflow
available_height = slide_height - top_margin - bottom_margin

# Validate that total table heights + spacing fits the slide
total_table_height = sum(table_heights)
if total_table_height > available_height:
    raise ValueError("The total table height exceeds the available slide height. Adjust the heights or reduce the number of tables.")

# Calculate dynamic spacing
spacing = (available_height - total_table_height) / (len(tables_data) - 1) if len(tables_data) > 1 else 0

# Start position for the first table
x_pos = Inches(0.5)  # Fixed horizontal position
y_pos = top_margin  # Start below the top margin

# Add tables to the slide
for i, (data, height) in enumerate(zip(tables_data, table_heights)):
    # Ensure all rows have the same number of columns
    max_cols = max(len(row) for row in data)
    padded_data = [row + [""] * (max_cols - len(row)) for row in data]

    rows, cols = len(padded_data), max_cols
    table = slide.shapes.add_table(rows, cols, x_pos, y_pos, table_width, height).table

    # Set column widths
    for col in range(cols):
        table.columns[col].width = table_width // cols

    # Populate table with data
    for row_idx, row_data in enumerate(padded_data):
        for col_idx, cell_data in enumerate(row_data):
            table.cell(row_idx, col_idx).text = cell_data
            # Adjust font size
            for paragraph in table.cell(row_idx, col_idx).text_frame.paragraphs:
                for run in paragraph.runs:
                    run.font.size = Pt(10)

    # Update vertical position for the next table
    y_pos += height + spacing

# Save the presentation
prs.save("three_tables_fixed.pptx")
print("PowerPoint presentation created successfully!")
# Out:
# PowerPoint presentation created successfully!

# %%
from pptx import Presentation
from pptx.util import Inches, Pt

# Create a PowerPoint presentation
prs = Presentation()

# Add a slide with a blank layout
slide = prs.slides.add_slide(prs.slide_layouts[5])

# Table data
company_details = [
    ["Company Details"],
    ["WEBSITE"],
    ["HQ ADDRESS"],
    ["ANNUAL GROWTH"],
    ["# OF EMPLOYEES"],
    ["INDUSTRY"]
]

key_contacts = [
    ["Key Contacts"],
    ["CEO/Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Finance", "Kartikeya\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
    ["Co-CEO/Co-Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Sales", "Gannuji\nph no:23234234\nmail:ganuradhakrish@gmail.com"]
]

rv_info = [
    ["RV Info"],
    ["WCIS_ID"],
    ["WCIS_SUP_ID"],
    ["WCIS_STATUS"],
    ["BDO"],
    ["RM"],
    ["Coverage Leads"],
    ["Last call reported by"],
    ["Last call reported on"],
    ["Call Logs"],
    ["Similar companies"]
]

# Define table data
tables_data = [company_details, key_contacts, rv_info]

# Constants
slide_width = prs.slide_width
slide_height = prs.slide_height
top_margin = Inches(0.5)  # Avoid title section
bottom_margin = Inches(0.5)  # Prevent overflow
x_pos = Inches(0.5)  # Fixed horizontal position
table_width = Inches(4)  # Fixed width for all tables
available_height = slide_height - top_margin - bottom_margin

# Calculate individual table height and spacing
table_heights = [Inches(1.5), Inches(2), Inches(2)]
total_table_height = sum(table_heights)
spacing = (available_height - total_table_height) / (len(tables_data) - 1)

if total_table_height + (spacing * (len(tables_data) - 1)) > available_height:
    raise ValueError("Tables and spacing exceed the available slide height.")

# Add tables to the slide
y_pos = top_margin
for i, (data, height) in enumerate(zip(tables_data, table_heights)):
    # Adjust table row and column data
    max_cols = max(len(row) for row in data)
    padded_data = [row + [""] * (max_cols - len(row)) for row in data]

    rows, cols = len(padded_data), max_cols
    table = slide.shapes.add_table(rows, cols, x_pos, y_pos, table_width, height).table

    # Set column widths
    for col in range(cols):
        table.columns[col].width = table_width // cols

    # Populate the table
    for row_idx, row_data in enumerate(padded_data):
        for col_idx, cell_data in enumerate(row_data):
            table.cell(row_idx, col_idx).text = cell_data
            # Set font size
            for paragraph in table.cell(row_idx, col_idx).text_frame.paragraphs:
                for run in paragraph.runs:
                    run.font.size = Pt(10)

    # Update y position for the next table
    y_pos += height + spacing

# Save the presentation
prs.save("three_tables_final.pptx")
print("PowerPoint file created successfully!")
# Out:
# PowerPoint file created successfully!

# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from datetime import datetime

# Create a PowerPoint presentation
prs = Presentation()

# Add a slide with a blank layout
slide = prs.slides.add_slide(prs.slide_layouts[5])

# Slide dimensions
slide_width = prs.slide_width
slide_height = prs.slide_height

# Title details
title_text = f"Company Name (prepared on {datetime.today().strftime('%Y-%m-%d')})"
title_left = Inches(1)
title_top = Inches(1)
title_width = slide_width - Inches(2)  # 1 inch margin on left and right

# Add the title
title_shape = slide.shapes.add_textbox(title_left, title_top, title_width, Inches(1))
title_frame = title_shape.text_frame
title_frame.text = title_text
title_frame.paragraphs[0].alignment = 1  # Center alignment
title_frame.paragraphs[0].font.size = Pt(18)

# Table data
company_details = [
    ["Company Details"],
    ["WEBSITE"],
    ["HQ ADDRESS"],
    ["ANNUAL GROWTH"],
    ["# OF EMPLOYEES"],
    ["INDUSTRY"]
]

key_contacts = [
    ["Key Contacts"],
    ["CEO/Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Finance", "Kartikeya\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
    ["Co-CEO/Co-Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Sales", "Gannuji\nph no:23234234\nmail:ganuradhakrish@gmail.com"]
]

rv_info = [
    ["RV Info"],
    ["WCIS_ID"],
    ["WCIS_SUP_ID"],
    ["WCIS_STATUS"],
    ["BDO"],
    ["RM"],
    ["Coverage Leads"],
    ["Last call reported by"],
    ["Last call reported on"],
    ["Call Logs"],
    ["Similar companies"]
]

# Define table data and widths
tables_data = [company_details, key_contacts, rv_info]
table_width = Inches(6)  # Fixed width for all tables

# Calculate available space and spacing
top_margin = Inches(1) + Inches(1) + Inches(1)  # Title + 1-inch gap
bottom_margin = Inches(1)
available_height = slide_height - top_margin - bottom_margin
total_gaps = Inches(1) * (len(tables_data) - 1)
table_height = (available_height - total_gaps) / len(tables_data)

# Validate if the height fits within the slide
if table_height <= 0:
    raise ValueError("Not enough space to fit all tables with the required gaps.")

# Add tables
x_pos = Inches(1)  # 1 inch from the left
y_pos = top_margin
for data in tables_data:
    # Ensure all rows have the same number of columns
    max_cols = max(len(row) for row in data)
    padded_data = [row + [""] * (max_cols - len(row)) for row in data]

    rows, cols = len(padded_data), max_cols
    table = slide.shapes.add_table(rows, cols, x_pos, y_pos, table_width, table_height).table

    # Set column widths
    for col in range(cols):
        table.columns[col].width = table_width // cols

    # Populate the table
    for row_idx, row_data in enumerate(padded_data):
        for col_idx, cell_data in enumerate(row_data):
            table.cell(row_idx, col_idx).text = cell_data
            # Set font size
            for paragraph in table.cell(row_idx, col_idx).text_frame.paragraphs:
                for run in paragraph.runs:
                    run.font.size = Pt(10)

    # Update y position for the next table
    y_pos += table_height + Inches(1)  # Add 1-inch gap

# Save the presentation
prs.save("structured_tables_presentation.pptx")
print("PowerPoint file created successfully!")
# Out:
# PowerPoint file created successfully!

# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from datetime import datetime

# Create a PowerPoint presentation
prs = Presentation()

# Add a slide with a blank layout
slide = prs.slides.add_slide(prs.slide_layouts[5])

# Slide dimensions
slide_width = prs.slide_width
print(slide_width)
slide_height = prs.slide_height
print(slide_height)

# Title configuration
title_text = f"NIKSUN Inc. (prepared on {datetime.today().strftime('%Y-%m-%d')})"
title_left = Inches(1)  # 1 inch from left
title_top = Inches(0.5)  # 1 inch from top
title_width = slide_width - Inches(2)  # Title spans the width, leaving 1-inch margin
title_height = Inches(0.5)

# Add title
title_shape = slide.shapes.add_textbox(title_left, title_top, title_width, title_height)
title_frame = title_shape.text_frame
title_frame.text = title_text
title_frame.paragraphs[0].alignment = 1  # Center-aligned
title_frame.paragraphs[0].font.size = Pt(18)

# Table data
company_details = [
    ["Company Details"],
    ["WEBSITE"],
    ["HQ ADDRESS"],
    ["ANNUAL GROWTH"],
    ["# OF EMPLOYEES"],
    ["INDUSTRY"]
]

key_contacts = [
    ["Key Contacts"],
    ["CEO/Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Finance", "Kartikeya\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
    ["Co-CEO/Co-Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Sales", "Gannuji\nph no:23234234\nmail:ganuradhakrish@gmail.com"]
]

rv_info = [
    ["RV Info"],
    ["WCIS_ID"],
    ["WCIS_SUP_ID"],
    ["WCIS_STATUS"],
    ["BDO"],
    ["RM"],
    ["Coverage Leads"],
    ["Last call reported by"],
    ["Last call reported on"],
    ["Call Logs"],
    ["Similar companies"]
]

# Table configurations
tables_data = [company_details, key_contacts, rv_info]
table_width = Inches(3)  # Fixed table width
top_margin = title_top + title_height + Inches(1)  # 1-inch gap below title
bottom_margin = Inches(1)
available_height = slide_height - top_margin - bottom_margin
table_gap = Inches(1)  # Fixed 1-inch gap between tables

# Calculate table height dynamically
num_tables = len(tables_data)
total_gaps = (num_tables - 1) * table_gap
table_height = (available_height - total_gaps) / num_tables

if table_height <= 0:
    raise ValueError("Insufficient space to place tables with the specified gaps.")

# Add tables to the slide
x_pos = Inches(1)  # Fixed 1-inch left margin
y_pos = top_margin

for data in tables_data:
    # Determine table size
    rows = len(data)
    cols = max(len(row) for row in data)
    padded_data = [row + [""] * (cols - len(row)) for row in data]

    # Add table
    table = slide.shapes.add_table(rows, cols, x_pos, y_pos, table_width, table_height).table

    # Set column widths
    for col in range(cols):
        table.columns[col].width = table_width // cols

    # Fill table with data
    for row_idx, row_data in enumerate(padded_data):
        for col_idx, cell_data in enumerate(row_data):
            table.cell(row_idx, col_idx).text = cell_data
            # Set font size
            for paragraph in table.cell(row_idx, col_idx).text_frame.paragraphs:
                for run in paragraph.runs:
                    run.font.size = Pt(10)

    # Update y-position for the next table
    y_pos += table_height + table_gap

# Save the presentation
output_file = "final_presentation.pptx"
prs.save(output_file)
print(f"PowerPoint file '{output_file}' created successfully!")
# Out:
# 9144000
# 6858000
# PowerPoint file 'final_presentation.pptx' created successfully!

# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from datetime import datetime

# Create a new PowerPoint presentation
prs = Presentation()

# Add a slide with a blank layout
slide = prs.slides.add_slide(prs.slide_layouts[5])

# Slide dimensions
slide_width = prs.slide_width
slide_height = prs.slide_height

# Title configuration
title_text = f"Company Name (prepared on {datetime.today().strftime('%Y-%m-%d')})"
title_left = Inches(1)  # 1 inch from the left
title_top = Inches(1)  # 1 inch from the top
title_width = slide_width - Inches(2)  # Width leaves 1-inch margins
title_height = Inches(0.5)

# Add title
title_shape = slide.shapes.add_textbox(title_left, title_top, title_width, title_height)
title_frame = title_shape.text_frame
title_frame.text = title_text
title_frame.paragraphs[0].alignment = 1  # Center-aligned
title_frame.paragraphs[0].font.size = Pt(18)

# Table data
company_details = [
    ["Company Details"],
    ["WEBSITE"],
    ["HQ ADDRESS"],
    ["ANNUAL GROWTH"],
    ["# OF EMPLOYEES"],
    ["INDUSTRY"]
]

key_contacts = [
    ["Key Contacts"],
    ["CEO/Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Finance", "Kartikeya\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
    ["Co-CEO/Co-Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Sales", "Gannuji\nph no:23234234\nmail:ganuradhakrish@gmail.com"]
]

rv_info = [
    ["RV Info", ""],
    ["WCIS_ID", "Coverage Leads"],
    ["WCIS_SUP_ID", "Last call reported by"],
    ["WCIS_STATUS", "Last call reported on"],
    ["BDO", "Call Logs"],
    ["RM", "Similar companies"]
]

# Table configurations
tables_data = [company_details, key_contacts, rv_info]
table_width = Inches(6)  # Fixed width for all tables
top_margin = title_top + title_height + Inches(1)  # 1-inch gap below title
bottom_margin = Inches(1)  # 1 inch gap from bottom
available_height = slide_height - top_margin - bottom_margin
table_gap = Inches(1)  # Fixed 1-inch gap between tables

# Calculate table height dynamically
num_tables = len(tables_data)
total_gaps = (num_tables - 1) * table_gap
table_height = (available_height - total_gaps) / num_tables

if table_height <= 0:
    raise ValueError("Insufficient space to place tables with the specified gaps.")

# Add tables to the slide
x_pos = Inches(1)  # Fixed 1-inch left margin
y_pos = top_margin

for data in tables_data:
    # Determine table size
    rows = len(data)
    cols = max(len(row) for row in data)
    padded_data = [row + [""] * (cols - len(row)) for row in data]

    # Add table
    table = slide.shapes.add_table(rows, cols, x_pos, y_pos, table_width, table_height).table

    # Set column widths
    for col in range(cols):
        table.columns[col].width = table_width // cols

    # Fill table with data
    for row_idx, row_data in enumerate(padded_data):
        for col_idx, cell_data in enumerate(row_data):
            table.cell(row_idx, col_idx).text = cell_data
            # Set font size
            for paragraph in table.cell(row_idx, col_idx).text_frame.paragraphs:
                for run in paragraph.runs:
                    run.font.size = Pt(10)

    # Update y-position for the next table
    y_pos += table_height + table_gap

# Save the presentation
output_file = "updated_presentation.pptx"
prs.save(output_file)
print(f"PowerPoint file '{output_file}' created successfully!")
# Out:
# PowerPoint file 'updated_presentation.pptx' created successfully!

# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from datetime import datetime

# Create a new PowerPoint presentation
prs = Presentation()

# Add a slide with a blank layout
slide = prs.slides.add_slide(prs.slide_layouts[5])

# Slide dimensions
slide_width = prs.slide_width
slide_height = prs.slide_height

# Title configuration
title_text = f"Company Name (prepared on {datetime.today().strftime('%Y-%m-%d')})"
title_left = Inches(1)  # 1 inch from the left
title_top = Inches(1)  # 1 inch from the top
title_width = slide_width - Inches(2)  # Width leaves 1-inch margins
title_height = Inches(0.5)

# Add title
title_shape = slide.shapes.add_textbox(title_left, title_top, title_width, title_height)
title_frame = title_shape.text_frame
title_frame.text = title_text
title_frame.paragraphs[0].alignment = 1  # Center-aligned
title_frame.paragraphs[0].font.size = Pt(18)

# Table data
company_details = [
    ["Company Details"],
    ["WEBSITE"],
    ["HQ ADDRESS"],
    ["ANNUAL GROWTH"],
    ["# OF EMPLOYEES"],
    ["INDUSTRY"]
]

key_contacts = [
    ["Key Contacts"],
    ["CEO/Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Finance", "Kartikeya\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
    ["Co-CEO/Co-Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com",
     "VP,Sales", "Gannuji\nph no:23234234\nmail:ganuradhakrish@gmail.com"]
]

rv_info = [
    ["RV Info", ""],
    ["WCIS_ID", "Coverage Leads"],
    ["WCIS_SUP_ID", "Last call reported by"],
    ["WCIS_STATUS", "Last call reported on"],
    ["BDO", "Call Logs"],
    ["RM", "Similar companies"]
]

# Table configurations
tables_data = [company_details, key_contacts, rv_info]
table_width = Inches(6)  # Fixed width for all tables
top_margin = title_top + title_height + Inches(1)  # 1-inch gap below title
bottom_margin = Inches(1)  # 1 inch gap from bottom
available_height = slide_height - top_margin - bottom_margin
table_gap = Inches(1)  # Fixed 1-inch gap between tables

# Calculate table height dynamically
num_tables = len(tables_data)
total_gaps = (num_tables - 1) * table_gap
table_height = (available_height - total_gaps) / num_tables

# Check if tables fit within the slide
if table_height <= 0:
    raise ValueError("Insufficient space to place tables with the specified gaps.")

# Add tables to the slide
x_pos = Inches(1)  # Fixed 1-inch left margin
y_pos = top_margin

for data in tables_data:
    # Determine table size
    rows = len(data)
    cols = max(len(row) for row in data)
    padded_data = [row + [""] * (cols - len(row)) for row in data]

    # Add table
    try:
        table = slide.shapes.add_table(rows, cols, x_pos, y_pos, table_width, table_height).table

        # Set column widths
        for col in range(cols):
            table.columns[col].width = table_width // cols

        # Fill table with data
        for row_idx, row_data in enumerate(padded_data):
            for col_idx, cell_data in enumerate(row_data):
                table.cell(row_idx, col_idx).text = cell_data
                # Set font size
                for paragraph in table.cell(row_idx, col_idx).text_frame.paragraphs:
                    for run in paragraph.runs:
                        run.font.size = Pt(10)

        # Update y-position for the next table
        y_pos += table_height + table_gap

    except Exception as e:
        print(f"Error adding table: {e}")
        break

# Save the presentation
output_file = "corrected_presentation.pptx"
prs.save(output_file)
print(f"PowerPoint file '{output_file}' created successfully!")
# Out:
# PowerPoint file 'corrected_presentation.pptx' created successfully!

# %%
from pptx import Presentation
from pptx.util import Inches, Pt

# Create a presentation object
prs = Presentation()

# Define slide dimensions (optional)
prs.slide_width = Inches(10)
prs.slide_height = Inches(7.5)

# Add a blank slide layout
slide_layout = prs.slide_layouts[5]  # Blank layout
slide = prs.slides.add_slide(slide_layout)

# Add the title 1 inch from the left and top, and center it
title_text = "Company name (prepared on today's date)"
title_shape = slide.shapes.add_textbox(Inches(1), Inches(1), Inches(8), Inches(1))
title_frame = title_shape.text_frame
title_frame.text = title_text
title_frame.paragraphs[0].alignment = 1  # Center alignment
title_frame.paragraphs[0].font.size = Pt(18)

# Data for the tables
company_details = [
    ["Company Details"],
    ["WEBSITE"],
    ["HQ ADDRESS"],
    ["ANNUAL GROWTH"],
    ["# OF EMPLOYEES"],
    ["INDUSTRY"],
]

key_contacts = [
    ["Key Contacts"],
    ["CEO/Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com", "VP, Finance", "Kartikeya\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
    ["Co-CEO/Co-Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com", "VP, Sales", "Gannuji\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
]

rv_info = [
    ["RV Info"],
    ["WCIS_ID", "Coverage Leads"],
    ["WCIS_SUP_ID", "Last call reported by"],
    ["WCIS_STATUS", "Last call reported on"],
    ["BDO", "Call Logs"],
    ["RM", "Similar companies"],
]

# Define the position and size for each table
table_width = Inches(8)
table_height = Inches(1.5)
left_margin = Inches(1)

top_margin = Inches(2.25)  # 1 inch below the title

# Create the tables and position them accordingly
# Table 1 (Company Details)
table1_top = top_margin

# Add the first table
table1 = slide.shapes.add_table(len(company_details), len(company_details[0]), left_margin, table1_top, table_width, table_height).table
for row_idx, row in enumerate(company_details):
    for col_idx, cell_text in enumerate(row):
        table1.cell(row_idx, col_idx).text = cell_text

# Table 2 (Key Contacts)
table2_top = table1_top + table_height + Inches(1)  # 1 inch gap between tables

# Add the second table
table2 = slide.shapes.add_table(len(key_contacts), len(key_contacts[0]), left_margin, table2_top, table_width, table_height).table
for row_idx, row in enumerate(key_contacts):
    for col_idx, cell_text in enumerate(row):
        table2.cell(row_idx, col_idx).text = cell_text

# Table 3 (RV Info)
table3_top = table2_top + table_height + Inches(1)  # 1 inch gap between tables

# Add the third table
table3 = slide.shapes.add_table(len(rv_info), len(rv_info[0]), left_margin, table3_top, table_width, table_height).table
for row_idx, row in enumerate(rv_info):
    for col_idx, cell_text in enumerate(row):
        table3.cell(row_idx, col_idx).text = cell_text

# Ensure the third table ends 1 inch from the bottom of the slide
bottom_margin = Inches(1)

# Save the presentation
prs.save("custom_layout_presentation.pptx")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-fdec4c117642> in <cell line: 70>()
#      70 for row_idx, row in enumerate(key_contacts):
#      71     for col_idx, cell_text in enumerate(row):
# ---> 72         table2.cell(row_idx, col_idx).text = cell_text
#      73
#      74 # Table 3 (RV Info)
#
# /usr/local/lib/python3.10/dist-packages/pptx/table.py in cell(self, row_idx, col_idx)
#      38         cell(0, 0) is the top, left cell in the table.
#      39         """
# ---> 40         return _Cell(self._tbl.tc(row_idx, col_idx), self)
#      41
#      42     @lazyproperty
#
# /usr/local/lib/python3.10/dist-packages/pptx/oxml/table.py in tc(self, row_idx, col_idx)
#     135     def tc(self, row_idx: int, col_idx: int) -> CT_TableCell:
#     136         """Return `a:tc` element at `row_idx`, `col_idx`."""
# ...

# %%
from pptx import Presentation
from pptx.util import Inches, Pt

# Create a presentation object
prs = Presentation()

# Define slide dimensions (optional)
prs.slide_width = Inches(10)
prs.slide_height = Inches(10)

# Add a blank slide layout
slide_layout = prs.slide_layouts[6]  # Blank layout
slide = prs.slides.add_slide(slide_layout)

# Add the title 1 inch from the left and top, and center it
title_text = "Company name (prepared on today's date)"
title_shape = slide.shapes.add_textbox(Inches(1), Inches(1), Inches(8), Inches(1))
title_frame = title_shape.text_frame
title_frame.text = title_text
title_frame.paragraphs[0].alignment = 1  # Center alignment
title_frame.paragraphs[0].font.size = Pt(5)

# Data for the tables
company_details = [
    ["Company Details"],
    ["WEBSITE"],
    ["HQ ADDRESS"],
    ["ANNUAL GROWTH"],
    ["# OF EMPLOYEES"],
    ["INDUSTRY"],
]

key_contacts = [
    ["Key Contacts"],
    ["CEO/Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com", "VP, Finance", "Kartikeya\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
    ["Co-CEO/Co-Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com", "VP, Sales", "Gannuji\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
]

rv_info = [
    ["RV Info"],
    ["WCIS_ID", "Coverage Leads"],
    ["WCIS_SUP_ID", "Last call reported by"],
    ["WCIS_STATUS", "Last call reported on"],
    ["BDO", "Call Logs"],
    ["RM", "Similar companies"],
]

# Define the position and size for each table
table_width = Inches(5)
table_height = Inches(1)
left_margin = Inches(1)

top_margin = Inches(1)  # 1 inch below the title

# Create the tables and position them accordingly
# Table 1 (Company Details)
table1_top = top_margin

# Add the first table
table1 = slide.shapes.add_table(len(company_details), max(len(row) for row in company_details), left_margin, table1_top, table_width, table_height).table
for row_idx, row in enumerate(company_details):
    for col_idx, cell_text in enumerate(row):
        if col_idx < len(row):
            table1.cell(row_idx, col_idx).text = cell_text

# Table 2 (Key Contacts)
table2_top = table1_top + table_height + Inches(1)  # 1 inch gap between tables

# Add the second table
table2 = slide.shapes.add_table(len(key_contacts), max(len(row) for row in key_contacts), left_margin, table2_top, table_width, table_height).table
for row_idx, row in enumerate(key_contacts):
    for col_idx, cell_text in enumerate(row):
        if col_idx < len(row):
            table2.cell(row_idx, col_idx).text = cell_text

# Table 3 (RV Info)
table3_top = table2_top + table_height + Inches(1)  # 1 inch gap between tables

# Add the third table
table3 = slide.shapes.add_table(len(rv_info), max(len(row) for row in rv_info), left_margin, table3_top, table_width, table_height).table
for row_idx, row in enumerate(rv_info):
    for col_idx, cell_text in enumerate(row):
        if col_idx < len(row):
            table3.cell(row_idx, col_idx).text = cell_text

# Ensure the third table ends 1 inch from the bottom of the slide
bottom_margin = Inches(1)

# Save the presentation
prs.save("custom_layout3_presentation.pptx")

# %%
for i, layout in enumerate(prs.slide_layouts):
    print(f"Layout {i}: {layout.name}")
# Out:
# Layout 0: Title Slide
# Layout 1: Title and Content
# Layout 2: Section Header
# Layout 3: Two Content
# Layout 4: Comparison
# Layout 5: Title Only
# Layout 6: Blank
# Layout 7: Content with Caption
# Layout 8: Picture with Caption
# Layout 9: Title and Vertical Text
# Layout 10: Vertical Title and Text

# %%
from pptx import Presentation
from pptx.util import Inches, Pt

# Create a presentation object
prs = Presentation()

# Define slide dimensions (optional)
prs.slide_width = Inches(20)
prs.slide_height = Inches(10)

# Add a blank slide layout
slide_layout = prs.slide_layouts[6]  # Blank layout
slide = prs.slides.add_slide(slide_layout)

# Add the title 1 inch from the left and top, and center it
title_text = "Company name (prepared on today's date)"
title_shape = slide.shapes.add_textbox(Inches(1), Inches(0.5), Inches(8), Inches(0.5))
title_frame = title_shape.text_frame
title_frame.text = title_text
title_frame.paragraphs[0].alignment = 1  # Center alignment
title_frame.paragraphs[0].font.size = Pt(18)

# Data for the tables
company_details = [
    ["Company Details"],
    ["WEBSITE"],
    ["HQ ADDRESS"],
    ["ANNUAL GROWTH"],
    ["# OF EMPLOYEES"],
    ["INDUSTRY"],
]

key_contacts = [
    ["Key Contacts"],
    ["CEO/Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com", "VP, Finance", "Kartikeya\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
    ["Co-CEO/Co-Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com", "VP, Sales", "Gannuji\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
]

rv_info = [
    ["RV Info"],
    ["WCIS_ID", "Coverage Leads"],
    ["WCIS_SUP_ID", "Last call reported by"],
    ["WCIS_STATUS", "Last call reported on"],
    ["BDO", "Call Logs"],
    ["RM", "Similar companies"],
]

# Define the position and size for each table
table_width = Inches(8)
table_height = Inches(1.5)
left_margin = Inches(1)

top_margin = Inches(2)  # 1 inch below the title

# Create the tables and position them accordingly
# Table 1 (Company Details)
table1_top = top_margin

# Add the first table
table1 = slide.shapes.add_table(len(company_details), max(len(row) for row in company_details), left_margin, table1_top, table_width, table_height).table
for row_idx, row in enumerate(company_details):
    for col_idx, cell_text in enumerate(row):
        if col_idx < len(row):
            table1.cell(row_idx, col_idx).text = cell_text

# Table 2 (Key Contacts)
table2_top = table1_top + table_height + Inches(1)  # 1 inch gap between tables

# Add the second table
table2 = slide.shapes.add_table(len(key_contacts), max(len(row) for row in key_contacts), left_margin, table2_top, table_width, table_height).table
for row_idx, row in enumerate(key_contacts):
    for col_idx, cell_text in enumerate(row):
        if col_idx < len(row):
            table2.cell(row_idx, col_idx).text = cell_text

# Table 3 (RV Info)
table3_top = table2_top + table_height + Inches(1)  # 1 inch gap between tables

# Add the third table
table3 = slide.shapes.add_table(len(rv_info), max(len(row) for row in rv_info), left_margin, table3_top, table_width, table_height).table
for row_idx, row in enumerate(rv_info):
    for col_idx, cell_text in enumerate(row):
        if col_idx < len(row):
            table3.cell(row_idx, col_idx).text = cell_text

# Ensure the third table ends 1 inch from the bottom of the slide
bottom_margin = Inches(1)

# Save the presentation
prs.save("custom_layout_presentation2.pptx")

# %%
from pptx import Presentation
from pptx.util import Inches, Pt

# Create a presentation object
prs = Presentation()

# Define slide dimensions (optional)
prs.slide_width = Inches(10)
prs.slide_height = Inches(7.5)

# Add a blank slide layout
slide_layout = prs.slide_layouts[5]  # Blank layout
slide = prs.slides.add_slide(slide_layout)

# Add the title 1 inch from the left and top, and center it
title_text = "Company name (prepared on today's date)"
title_shape = slide.shapes.add_textbox(Inches(1), Inches(1), Inches(8), Inches(1))
title_frame = title_shape.text_frame
title_frame.text = title_text
title_frame.paragraphs[0].alignment = 1  # Center alignment
title_frame.paragraphs[0].font.size = Pt(18)

# Data for the tables
company_details = [
    ["Company Details"],
    ["WEBSITE"],
    ["HQ ADDRESS"],
    ["ANNUAL GROWTH"],
    ["# OF EMPLOYEES"],
    ["INDUSTRY"],
]

key_contacts = [
    ["Key Contacts"],
    ["CEO/Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com", "VP, Finance", "Kartikeya\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
    ["Co-CEO/Co-Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com", "VP, Sales", "Gannuji\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
]

rv_info = [
    ["RV Info"],
    ["WCIS_ID", "Coverage Leads"],
    ["WCIS_SUP_ID", "Last call reported by"],
    ["WCIS_STATUS", "Last call reported on"],
    ["BDO", "Call Logs"],
    ["RM", "Similar companies"],
]

# Define the width for each table
table_width = Inches(8)
left_margin = Inches(1)

# Add the first table (Company Details)
top_margin = Inches(2)  # 1 inch below the title
table1_height = Inches(1.5)  # Adjust as needed
table1_top = top_margin
table1 = slide.shapes.add_table(len(company_details), len(company_details[0]), left_margin, table1_top, table_width, table1_height).table
for row_idx, row in enumerate(company_details):
    for col_idx, cell_text in enumerate(row):
        cell = table1.cell(row_idx, col_idx)
        cell.text = cell_text
        cell.text_frame.word_wrap = True  # Enable text wrapping

# Add the second table (Key Contacts)
table2_top = table1_top + table1_height + Inches(1)  # 1 inch gap between tables
table2_height = Inches(1.5)  # Adjust as needed
table2 = slide.shapes.add_table(len(key_contacts), len(key_contacts[0]), left_margin, table2_top, table_width, table2_height).table
for row_idx, row in enumerate(key_contacts):
    for col_idx, cell_text in enumerate(row):
        cell = table2.cell(row_idx, col_idx)
        cell.text = cell_text
        cell.text_frame.word_wrap = True  # Enable text wrapping

# Add the third table (RV Info)
table3_top = table2_top + table2_height + Inches(1)  # 1 inch gap between tables
table3_height = Inches(1.5)  # Adjust as needed
table3 = slide.shapes.add_table(len(rv_info), len(rv_info[0]), left_margin, table3_top, table_width, table3_height).table
for row_idx, row in enumerate(rv_info):
    for col_idx, cell_text in enumerate(row):
        cell = table3.cell(row_idx, col_idx)
        cell.text = cell_text
        cell.text_frame.word_wrap = True  # Enable text wrapping

# Ensure the third table ends 1 inch from the bottom of the slide
bottom_margin = Inches(1)

# Save the presentation
prs.save("custom_layout_presentation21.pptx")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-f222e1f93cb9> in <cell line: 67>()
#      67 for row_idx, row in enumerate(key_contacts):
#      68     for col_idx, cell_text in enumerate(row):
# ---> 69         cell = table2.cell(row_idx, col_idx)
#      70         cell.text = cell_text
#      71         cell.text_frame.word_wrap = True  # Enable text wrapping
#
# /usr/local/lib/python3.10/dist-packages/pptx/table.py in cell(self, row_idx, col_idx)
#      38         cell(0, 0) is the top, left cell in the table.
#      39         """
# ---> 40         return _Cell(self._tbl.tc(row_idx, col_idx), self)
#      41
#      42     @lazyproperty
#
# /usr/local/lib/python3.10/dist-packages/pptx/oxml/table.py in tc(self, row_idx, col_idx)
#     135     def tc(self, row_idx: int, col_idx: int) -> CT_TableCell:
# ...

# %%
from pptx import Presentation
from pptx.util import Inches, Pt

# Create a presentation object
prs = Presentation()

# Define slide dimensions (optional)
prs.slide_width = Inches(20)
prs.slide_height = Inches(10)

# Add a blank slide layout
slide_layout = prs.slide_layouts[6]  # Blank layout
slide = prs.slides.add_slide(slide_layout)

# Add the title 1 inch from the left and top, and center it
title_text = "Company name (prepared on today's date)"
title_shape = slide.shapes.add_textbox(Inches(1), Inches(1), Inches(8), Inches(1))
title_frame = title_shape.text_frame
title_frame.text = title_text
title_frame.paragraphs[0].alignment = 1  # Center alignment
title_frame.paragraphs[0].font.size = Pt(18)

# Data for the tables
company_details = [
    ["Company Details"],
    ["WEBSITE"],
    ["HQ ADDRESS"],
    ["ANNUAL GROWTH"],
    ["# OF EMPLOYEES"],
    ["INDUSTRY"],
]

key_contacts = [
    ["Key Contacts", "", "", ""],  # Padded with empty strings
    ["CEO/Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com", "VP, Finance", "Kartikeya\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
    ["Co-CEO/Co-Founder", "Nandana\nph no:23234234\nmail:ganuradhakrish@gmail.com", "VP, Sales", "Gannuji\nph no:23234234\nmail:ganuradhakrish@gmail.com"],
]


rv_info = [
    ["RV Info",""],
    ["WCIS_ID", "Coverage Leads"],
    ["WCIS_SUP_ID", "Last call reported by"],
    ["WCIS_STATUS", "Last call reported on"],
    ["BDO", "Call Logs"],
    ["RM", "Similar companies"],
]

# Ensure all sublists in the data are the same length
max_columns_company = max(len(row) for row in company_details)
max_columns_key = max(len(row) for row in key_contacts)
max_columns_rv = max(len(row) for row in rv_info)

# Verify the data structures have uniform row lengths
for idx, row in enumerate(company_details):
    if len(row) != max_columns_company:
        raise ValueError(f"Row {idx} in 'company_details' has inconsistent column length.")

for idx, row in enumerate(key_contacts):
    if len(row) != max_columns_key:
        raise ValueError(f"Row {idx} in 'key_contacts' has inconsistent column length.")

for idx, row in enumerate(rv_info):
    if len(row) != max_columns_rv:
        raise ValueError(f"Row {idx} in 'rv_info' has inconsistent column length.")

# Define the width for each table
table_width = Inches(8)
left_margin = Inches(1)

# Add the first table (Company Details)
top_margin = Inches(2.25)  # 1 inch below the title
table1_height = Inches(1.5)  # Adjust as needed
table1_top = top_margin
table1 = slide.shapes.add_table(len(company_details), max_columns_company, left_margin, table1_top, table_width, table1_height).table
for row_idx, row in enumerate(company_details):
    for col_idx, cell_text in enumerate(row):
        cell = table1.cell(row_idx, col_idx)
        cell.text = cell_text
        cell.text_frame.word_wrap = True  # Enable text wrapping

# Add the second table (Key Contacts)
table2_top = table1_top + table1_height + Inches(1)  # 1 inch gap between tables
table2_height = Inches(1.5)  # Adjust as needed
table2 = slide.shapes.add_table(len(key_contacts), max_columns_key, left_margin, table2_top, table_width, table2_height).table
for row_idx, row in enumerate(key_contacts):
    for col_idx, cell_text in enumerate(row):
        cell = table2.cell(row_idx, col_idx)
        cell.text = cell_text
        cell.text_frame.word_wrap = True  # Enable text wrapping

# Add the third table (RV Info)
table3_top = table2_top + table2_height + Inches(1.25)  # 1 inch gap between tables
table3_height = Inches(1.5)  # Adjust as needed
table3 = slide.shapes.add_table(len(rv_info), max_columns_rv, left_margin, table3_top, table_width, table3_height).table
for row_idx, row in enumerate(rv_info):
    for col_idx, cell_text in enumerate(row):
        cell = table3.cell(row_idx, col_idx)
        cell.text = cell_text
        cell.text_frame.word_wrap = True  # Enable text wrapping

# Ensure the third table ends 1 inch from the bottom of the slide
bottom_margin = Inches(1)

# Save the presentation
prs.save("custom_layout_presentation12.pptx")
